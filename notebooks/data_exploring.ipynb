# %%
import pandas as pd

# %%
#load data from csv
data = pd.read_csv('top_tracks.csv')

# %%
data
# Out:
#                                 track_name                 artist_name  \
# 0                         Die With A Smile       Lady Gaga, Bruno Mars
# 1                       A Bar Song (Tipsy)                   Shaboozey
# 2                       BIRDS OF A FEATHER               Billie Eilish
# 3                                    Smile               Morgan Wallen
# 4                                     APT.            ROSÉ, Bruno Mars
# ..                                     ...                         ...
# 184                            Stay Strong                 Titus Drott
# 185                         Qué Pasaría...   Rauw Alejandro, Bad Bunny
# 186                            I Miss Love                       CLYDE
# 187  I Had Some Help (Feat. Morgan Wallen)  Post Malone, Morgan Wallen
# 188                              Your Love               Linda Englund
#
#                album_name release_date  popularity                track_id  \
# 0        Die With A Smile   2024-08-16         100  2plbrEY59IikOBgBGLjaoe
# 1      A Bar Song (Tipsy)   2024-04-12          85  2FQrifJ1N335Ljm3TjTVVf
# 2    HIT ME HARD AND SOFT   2024-05-17          97  6dOtVTDdiauQNBQEDOtlAB
# 3                   Smile   2024-12-31          83  3MJ6lFNV12FSHAOzTzkwxz
# 4                    APT.   2024-10-18          96  5vNRhkKd0yEAg8suGBpjeY
# ..                    ...          ...         ...                     ...
# 184   Writing In The Dark   2024-11-29          19  1mntZnBihxbiPb5pSX0eJg
# 185          Cosa Nuestra   2024-11-15          91  0l0vcZMU7AOeQmUIREoI2U
# 186           I Miss Love   2024-12-06          20  4cBZaf9OI7oaMYuzG9sYDl
# 187          F-1 Trillion   2024-08-15          84  5IZXB5IKAD2qlvTPJYDCFB
# 188             Your Love   2025-01-10           9  4LnjQsDrTCNbng93mBV9bf
#
#      region
# 0    Global
# 1    Global
# 2    Global
# 3    Global
# 4    Global
# ..      ...
# 184     USA
# 185     USA
# 186     USA
# 187     USA
# 188     USA
#
# [189 rows x 7 columns]

# %% [markdown]
# There are many duplicates, as expected.
# maybe use them for analysis instead of removing?
